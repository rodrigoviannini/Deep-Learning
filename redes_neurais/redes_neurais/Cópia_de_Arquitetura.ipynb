# %% [markdown]
# # Definindo uma Arquitetura no PyTorch

# %% [markdown]
# **Carregando dados**
#
# Exemplo de dados não-linearmente separáveis (distribuição em lua): <br>
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

X1, Y1 = make_moons(n_samples=300, noise=0.2)
plt.scatter(X1[:, 0], X1[:, 1], marker='o', 
 c=Y1, s=25, edgecolor='k')

# %% [markdown]
# ## nn.Sequential
#
# O módulo ```nn.Sequential``` é um container onde se pode colocar múltiplos módulos. Ao realizar um ```forward``` em um objeto ```Sequential``` ele aplicará sequencialmente os módulos nele contidas para gerar uma saída.
#
# Segue abaixo um exemplo desse módulo contendo 2 camadas ```Linear``` intercaladas por uma função de ativação ```ReLU```.

# %%
import torch
from torch import nn # neural networks

input_size = 2                                                                  # tamanho da entrada
hidden_size = 8                                                                 
output_size = 1                                                                 # camada de saida

net = nn.Sequential(nn.Linear(in_features=input_size, out_features=hidden_size),  # hidden (escondida) => hiperparametros
                    nn.ReLU(),                                                    # ativação não linear
                    nn.Linear(in_features=hidden_size, out_features=output_size)) # output (saída)
print(net)

# quanto mais hiperparametros mais complexo é o modelo
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=8, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=8, out_features=1, bias=True)
# )

# %% [markdown]
# O módulo ```summary``` da biblioteca **```torchsummary```** nos permite visualizar mais informações sobre a nossa rede, como quantidade de parâmetros e o tamanho que cada elemento ocupa na memória.
#
# Para mais informações, acesse: https://github.com/sksq96/pytorch-summary

# %%
from torchsummary import summary
summary(net, input_size=(1, input_size)) # nao roda se tiver na GPU

'''
        Linear-1                 [-1, 1, 8]              24 parametros
        ReLU-2                   [-1, 1, 8]               0
        Linear-3                 [-1, 1, 1]               9 Um perceptron de saída conectado a oito neuronios na camada escondida
'''
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-695f0b172e88> in <module>()
#       1 from torchsummary import summary
# ----> 2 summary(net, input_size=(1, input_size)) # nao roda se tiver na GPU
#       3
#       4 '''
#       5         Linear-1                 [-1, 1, 8]              24 parametros
#
# /usr/local/lib/python3.7/dist-packages/torchsummary/torchsummary.py in summary(model, input_size, batch_size, device)
#      70     # make a forward pass
#      71     # print(x.shape)
# ---> 72     model(*x)
#      73
#      74     # remove these hooks
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1126             input = bw_hook.setup_input_hook(input)
#    1127
# -> 1128         result = forward_call(*input, **kwargs)
#    1129         if _global_forward_hooks or self._forward_hooks:
#    1130             for hook in (*_global_forward_hooks.values(), *self._forward_hooks.values()):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu! (when checking argument for argument mat2 in method wrapper_mm)

# %% [markdown]
# ### Forward

# %%
## Se for lista, mas como nao é segue o notebook debaixo
print(X1.dtype)
tensor = torch.Tensor(X1)       # transformar a entrada em um tensor
pred   = net(tensor)            # chamar a rede e passar o tensor de entrada
# Out:
# float64

# %%
# Sendo array sexecuta assim
print(X1.shape)
tensor = torch.from_numpy(X1).float() # usa esse float qdo recebo um float64 e minha aplicação só aceita float32
pred   = net(tensor)
print(pred.size())
# Out:
# (300, 2)
# torch.Size([300, 1])

# %% [markdown]
# ## Classe nn.Module

# %% [markdown]
# A forma mais organizada de definir modelos em PyTorch é implementando uma classe nos moldes da classe ```nn.Module```. Para redes pequenas, como as que estamos aprendendo até o momento, sua importância pode não se destacar, mas modelos maiores e com funcionalidades mais complexas, são mais fáceis de implementar e realizar manutenções dessa forma.
#
# Funções obrigatórias do ```nn.Module```.
# * ```__init()__```: definição de hiperparâmetros e instância do modelo
# * ```forward()```: Fluxo da entrada para produzir uma saída

# %%
class MinhaRede(nn.Module):                                                      # nn.Module ==> subclasse da classe Module           
  
  def __init__(self, input_size, hidden_size, output_size):
    super(MinhaRede, self).__init__()                                           # inicializando a classe mãe
    
    # Definir a arquitetura
    self.hidden = nn.Linear(input_size, hidden_size)
    self.relu   = nn.ReLU()
    self.output = nn.Linear(hidden_size, output_size)
    
  def forward(self, X):
    
    # Gerar uma saída a partir do X
    hidden = self.relu(self.hidden(X))                                          # camada escondida passa pela camada de ativação
    output = self.output(hidden) 
    
    return output

# %% [markdown]
# Instanciando a rede

# %%
input_size = 2
hidden_size = 8
output_size = 1

net = MinhaRede(input_size,hidden_size, output_size)  ## Chama implicitamente: O método __init__()
print(net)
# Out:
# MinhaRede(
#   (hidden): Linear(in_features=2, out_features=8, bias=True)
#   (relu): ReLU()
#   (output): Linear(in_features=8, out_features=1, bias=True)
# )

# %% [markdown]
# ### Forward

# %%
print(X1.shape)
tensor = torch.from_numpy(X1).float()
pred   = net(tensor)
print(pred.size())
# Out:
# (300, 2)
# torch.Size([300, 1])

# %% [markdown]
# ## Subindo informações na GPU
#
# Para conseguir executar modelos maiores em tempo hábil, é preciso carregar as informação na GPU para que o processamento seja realizado por ela. Dentre as informações que conhecemos até o momento, duas delas precisam ser carregadas ba GPU:
# * Entrada
# * Rede
#
# A célula a seguir contém a implementação sugerida para realizar esse processo. <br>
# Se certifique que o notebook está na configuração desejada (CPU/GPU). Para isso, basta acessar ```Edit -> Notebook Settings``` e definir o hardware desejado.

# %%
if torch.cuda.is_available():
  device = torch.device('cuda')
else:
  device = torch.device('cpu')
  
print(device)
# Out:
# cuda

# %%
input_size = 2
hidden_size = 8
output_size = 1

net = MinhaRede(input_size,hidden_size, output_size)                            ## O método __init__()
net = net.to(device)                                                            # subir na GPU
print(net)
# Out:
# MinhaRede(
#   (hidden): Linear(in_features=2, out_features=8, bias=True)
#   (relu): ReLU()
#   (output): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
print(X1.shape)
tensor = torch.from_numpy(X1).float()
tensor = tensor.to(device)
# print(tensor)
pred   = net(tensor)
print(pred.size())
# Out:
# (300, 2)
# torch.Size([300, 1])
